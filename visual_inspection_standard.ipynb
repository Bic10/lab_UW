# %%
import numpy as np
from math import floor, ceil
from random import randint, choice
from scipy.stats import norm
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
from tqdm import tqdm
from tqdm.autonotebook import tqdm
import time as tm
import multiprocessing as mp   
from LAB_UW_functions import *
# Out:
# /tmp/ipykernel_16974/1139959824.py:10: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
###### INPUT #######

machine_name = "Brava_2"
experiment_name = "s0108"
data_type = "data_tsv_files"

### Some plot features ###
image_types = ("waveforms","amplitude_maps","amplitude_spectrum_maps", "example_of_filtered_spectrum","example_of_filtered_waveform")
formato = '.png'
remove_initial_samples = 200    # number of samples to be removed at the beginning, to get rid of the noise burst.
highlight_start = 0
highlight_end = 0
xlim_plot= 50
ticks_steps_waveforms = 2 #[microseconds] plot ticks 
step_wf_to_plot = 100  # get one waveforms each step_wf_to_plot 
amp_scale = 300  #color map for amplitude scale
freq_cut = 5   # [Hz] lowpass frequency threshold 


infile_path_list = make_infile_path_list(machine_name,experiment_name,  data_type = data_type)
outdir_path_images = make_images_folders(machine_name, experiment_name, image_types)       

for infile_path in sorted(infile_path_list):
    print('PROCESSING UW DATA IN %s: ' %infile_path)

    data,metadata = make_UW_data(infile_path)
    data,metadata = remove_starting_noise(data, metadata, remove_initial_samples)

    #CHOOSE THE FILE PATH OF THE OUTPUT. Add here a line for each type of images you want and call the relative plot function with the choosen path
    outfile_name = os.path.basename(infile_path).split('.')[0]    # remove extension

    outfile_path_waveforms = os.path.join(outdir_path_images[0], outfile_name)
    outfile_path_amp_map = os.path.join(outdir_path_images[1], outfile_name)
    outfile_path_spectrum_map = os.path.join(outdir_path_images[2], outfile_name)
    outfile_path_example_filtered_spectrum = os.path.join(outdir_path_images[3], outfile_name)
    outfile_path_example_original_vs_filtered = os.path.join(outdir_path_images[4], outfile_name)


    ## PLOT DATA ###
    start_time = tm.time()
    uw_all_plot(data, metadata, step_wf_to_plot, highlight_start, highlight_end, 
                xlim_plot, ticks_steps_waveforms, outfile_path = outfile_path_waveforms, formato = formato)
    amplitude_map(data,metadata, amp_scale, outfile_path=outfile_path_amp_map, formato = formato)

    # FILTER WITH A LOWPASS AND PLOT THE AMPLITUDE MAP OF THE SPECTRUM
    filtered_data, noise_recostructed = signal2noise_separation_lowpass(data, metadata, freq_cut=freq_cut, outfile_path= outfile_path_spectrum_map, formato=formato )

    # PLOT THE FILTERED DATA IN THE SAME FOLDERS OF THE ORIGINAL DATA
    uw_all_plot(filtered_data, metadata, step_wf_to_plot, highlight_start, highlight_end, 
                xlim_plot, ticks_steps_waveforms, outfile_path = outfile_path_waveforms + "_filtered", formato = formato)
    amplitude_map(filtered_data,metadata, amp_scale,outfile_path = outfile_path_amp_map + "_filtered", formato = formato)

    wave_chosed = randint(0,metadata['number_of_waveforms'])
    single_waveform = data[wave_chosed,:]
    filtered_single_waveform, filtered_noise_recostructed = signal2noise_separation_lowpass(single_waveform, metadata, freq_cut=freq_cut, outfile_path=outfile_path_example_filtered_spectrum)
    signal_vs_filtered_signal_plot(single_waveform, filtered_single_waveform, metadata, freq_cut=freq_cut, outfile_path = outfile_path_example_original_vs_filtered, )


    print("--- %s seconds for processing %s---" % (tm.time() - start_time, outfile_name))
# Out:
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/001_run_in_10MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/001_run_in_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/001_run_in_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/001_run_in_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/001_run_in_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/001_run_in_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/001_run_in_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/001_run_in_10MPa
# --- 16.1882107257843 seconds for processing 001_run_in_10MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/002_step_1_3_1_10MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/002_step_1_3_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/002_step_1_3_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/002_step_1_3_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/002_step_1_3_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/002_step_1_3_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/002_step_1_3_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/002_step_1_3_1_10MPa
# --- 18.858965158462524 seconds for processing 002_step_1_3_1_10MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/003_step_1_10_1_10MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/003_step_1_10_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/003_step_1_10_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/003_step_1_10_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/003_step_1_10_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/003_step_1_10_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/003_step_1_10_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/003_step_1_10_1_10MPa
# --- 17.59092664718628 seconds for processing 003_step_1_10_1_10MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/004_step_1_30_1_10MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/004_step_1_30_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/004_step_1_30_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/004_step_1_30_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/004_step_1_30_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/004_step_1_30_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/004_step_1_30_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/004_step_1_30_1_10MPa
# --- 57.80276656150818 seconds for processing 004_step_1_30_1_10MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/005_step_1_100_1_10MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/005_step_1_100_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/005_step_1_100_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/005_step_1_100_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/005_step_1_100_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/005_step_1_100_1_10MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/005_step_1_100_1_10MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/005_step_1_100_1_10MPa
# --- 56.01549577713013 seconds for processing 005_step_1_100_1_10MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/006_run_in_20MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/006_run_in_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/006_run_in_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/006_run_in_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/006_run_in_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/006_run_in_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/006_run_in_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/006_run_in_20MPa
# --- 13.21095609664917 seconds for processing 006_run_in_20MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/007_step_1_10_1_20MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/007_step_1_10_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/007_step_1_10_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/007_step_1_10_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/007_step_1_10_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/007_step_1_10_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/007_step_1_10_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/007_step_1_10_1_20MPa
# --- 13.48004412651062 seconds for processing 007_step_1_10_1_20MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/008_step_1_30_1_20MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/008_step_1_30_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/008_step_1_30_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/008_step_1_30_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/008_step_1_30_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/008_step_1_30_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/008_step_1_30_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/008_step_1_30_1_20MPa
# --- 56.2621488571167 seconds for processing 008_step_1_30_1_20MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/009_step_1_100_1_20MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/009_step_1_100_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/009_step_1_100_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/009_step_1_100_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/009_step_1_100_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/009_step_1_100_1_20MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/009_step_1_100_1_20MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/009_step_1_100_1_20MPa
# --- 53.80620455741882 seconds for processing 009_step_1_100_1_20MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/010_run_in_30MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/010_run_in_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/010_run_in_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/010_run_in_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/010_run_in_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/010_run_in_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/010_run_in_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/010_run_in_30MPa
# --- 14.212013483047485 seconds for processing 010_run_in_30MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/011_step_1_10_1_30MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/011_step_1_10_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/011_step_1_10_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/011_step_1_10_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/011_step_1_10_1_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/011_step_1_10_1_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/011_step_1_10_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/011_step_1_10_1_30MPa
# --- 16.558607578277588 seconds for processing 011_step_1_10_1_30MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/012_step_1_30_1_30MPa.bscan.tsv:
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/012_step_1_30_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/012_step_1_30_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_spectrum_maps/012_step_1_30_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/waveforms/012_step_1_30_1_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/amplitude_maps/012_step_1_30_1_30MPa_filtered
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_spectrum/012_step_1_30_1_30MPa
# Plot saved to /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/images/example_of_filtered_waveform/012_step_1_30_1_30MPa
# --- 53.47015690803528 seconds for processing 012_step_1_30_1_30MPa---
# PROCESSING UW DATA IN /home/michele/Desktop/Dottorato/active_source_implementation/experiments_Brava_2/s0108/data_tsv_files/013_step_1_100_1_30MPa.bscan.tsv:
